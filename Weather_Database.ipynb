# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
# print out the list of tuples of longtitude land latitude
print(coordinates)
# Out:
# [(-58.22646398296435, 178.15023367943007), (73.1663993054458, -60.62941395485939), (-73.02351083703007, -104.82356819020515), (-29.265490829061612, -116.47509438227067), (-48.315687777393755, 85.42146868666345), (-1.7744504054555676, -138.9582154353418), (-80.21603679353788, -114.83919752217236), (59.46341026927291, 159.67917932955123), (49.51571063083725, -118.99638947671615), (-12.027929168739746, 75.20839337068975), (56.197228986854384, -5.344474493672124), (-55.960515136896056, -96.7074314091031), (-33.08007269528366, -28.350734243243238), (-82.55389489176287, -158.9328166405807), (-33.41247419424969, 122.96696938527953), (-2.367430223674205, 62.1888215793704), (87.78569193440734, -176.1804235174017), (-39.38573283934127, 74.02593134994504), (-30.720159799284737, 7.7237041696297695), (-30.11227014730661, -80.93260893899237), (35.247424358930175, 115.74092073480023), (78.09784670496092, 26.99176904335073), (-50.21889946424372, -43.86038217279199), (-14.872737781195298, -98.77221701764132), (-48.83876161097076, 113.17574787910416), (-15.22711622549032, 173.00924894281889), (51.22067862743424, -174.7927854426347), (-45.7498186453223, 163.6293968878478), (4.27231797185064, 25.812563151103177), (19.36644546530522, -31.857037631165895), (15.376032237108376, 60.27121029656249), (-50.16847980070859, -39.15240762699892), (-60.30003472929387, -30.69845719627483), (75.84382021224815, 171.64528393533857), (72.06486829867393, -10.316283108677112), (84.61584289357498, 55.20678992626827), (84.51436497892468, 36.62106218684829), (56.86048059239215, -52.88967184244065), (-8.63361592114525, 113.081729525394), (73.5496797239058, -80.87018240364505), (-27.460627105707005, 127.95049706242071), (-86.3089014851173, 173.5035245953918), (-23.27986726790246, -106.73894024321675), (-34.93457433138357, -136.98474489130584), (5.0326270751285165, 53.40640398387504), (1.1673608932664763, -41.43018518629668), (-75.3985594364695, 10.427701763461386), (71.78353554085095, -76.3121908885214), (-41.307525896786544, -157.03294976042156), (-88.18114869213991, 159.45615468179807), (-10.697874964106106, -176.70625700441005), (43.71532866973695, -84.67249136138828), (-48.18346740363904, 117.86945675757613), (7.962769217555987, -177.89137097637092), (-8.19863630862234, 4.519402654503324), (-28.04070226541255, 58.54942408435076), (53.479801498018276, -52.738376659398966), (-72.16273515643947, -125.60478898813155), (-86.5177736191621, -25.474367708054103), (-68.3548205098066, -72.87514111904126), (63.3310628295518, -171.8787695775027), (9.956395647984849, -22.778593501227306), (43.20754747609652, 43.39259356647915), (-65.59353911160004, 5.429195766427426), (53.52008138616185, 169.95057704823245), (-61.2527992870565, 6.2453429983502815), (-18.98303460583682, -39.65397532841578), (-68.10002828986165, 118.84903309992745), (-37.89945225135211, 104.31105686617826), (-42.23319176924698, 146.5984818281877), (-65.37905138672559, -106.65578709113522), (87.41758844603649, -122.32467592397953), (-80.3369861376214, -133.6951420550992), (-72.92584263472887, 136.60722629028368), (75.25284687458941, -115.79182324743496), (-27.093134452646808, 4.880345951616192), (-13.35519399107595, 123.96620231753923), (47.30823762421309, -90.30809521684036), (5.048143878533864, 7.528058296207007), (9.082764384010659, -165.61604062453358), (-60.478306528460415, -28.78596595383675), (76.5576062077221, -20.49802354983447), (75.45612748229726, 164.80892995092654), (-50.95218651453264, 6.655112881627872), (5.750742872610402, -99.47456591141197), (38.999659117452325, -140.2461788822874), (2.150972096830884, 33.36103780304563), (-70.15035292320977, -92.20894249332159), (15.048653288675851, -137.13514541354215), (52.16913239666323, -110.50728942475733), (26.431309199209267, 131.8940721766191), (-33.072909426731236, -86.92209609933107), (-16.325075225142726, 148.46316821972454), (-52.66084008290926, -45.93803202239417), (69.54143237646653, 119.58970121718284), (-52.37931960388246, 95.61035723397379), (-22 ...

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 796

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
# Built-in API request by city name
# You can call by city name or city name, state code and country code. Please note that searching by states available only for the USA locations.

# API call

# https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
url = "https://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        #print(city_weather)
        name = city_weather['name']
        latitude = city_weather['coord']['lat']
        longitude = city_weather['coord']['lon']
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        cloudiness = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather['sys']['country']
        description = city_weather['weather'][0]['description']
#         print(latitude, longitude, max_temp, humidity, cloudiness, wind, country,description)


        # Append the city information into the city_data list
        city_data.append({"City": name,
                          "Lat": latitude,
                          "Lng": longitude,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": cloudiness,
                          "Wind Speed": wind,
                          "Country": country,
                          "Current Description": description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# print(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dunedin
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | palana
# Processing Record 8 of Set 1 | penticton
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | lochgilphead
# Processing Record 11 of Set 1 | arraial do cabo
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | luderitz
# Processing Record 18 of Set 1 | coquimbo
# Processing Record 19 of Set 1 | dingtao
# Processing Record 20 of Set 1 | mehamn
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | vila
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | zemio
# Processing Record 28 of Set 1 | ponta do sol
# Processing Record 29 of Set 1 | salalah
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | hofn
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | vardo
# Processing Record 35 of Set 1 | paamiut
# Processing Record 36 of Set 1 | kencong
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | yulara
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | eyl
# Processing Record 41 of Set 1 | tutoia
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 1 | mount pleasant
# Processing Record 46 of Set 1 | mayumba
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | saint anthony
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | praia
# Processing Record 1 of Set 2 | verkhnyaya balkariya
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | sao mateus
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | kupang
# Processing Record 9 of Set 2 | thunder bay
# Processing Record 10 of Set 2 | aba
# Processing Record 11 of Set 2 | makakilo city
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | bilibino
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | puerto escondido
# Processing Record 16 of Set 2 | fortuna
# Processing Record 17 of Set 2 | kaberamaido
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | provost
# Processing Record 20 of Set 2 | naze
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | innisfail
# Processing Record 23 of Set 2 | zhigansk
# Processing Record 24 of Set 2 | hualmay
# Processing Record 25 of Set 2 | westport
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | bozoum
# Processing Record 28 of Set 2 | banjar
# Processing Record 29 of Set 2 | port macquarie
# Processing Record 30 of Set 2 | simpang
# Processing Record 31 of Set 2 | takoradi
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | general roca
# Processing Record 35 of Set 2 | mendahara
# City not found. Skipping...
# Processing Record 36 of Set 2 | burica
# City not found. Skipping...
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | manali
# Processing Record 43 of Set 2 | bibiani
# Processing Record 44 of Set 2 | calama
# Processing Record 45 of Set 2 | grindavik
# Processing Record 46 of Set 2 | kapoeta
# Processing Record 47 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | chokurdakh
# Processing Record 50 of Set 2 | nanakuli
# Processing Record 1 of Set 3 | kaoma
# Processing Record 2 of Set 3 | kimbe
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | baisha
# Processing Record 5 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 3 | chapais
# Processing Record 7 of Set 3 | altay
# Processing Record 8 of Set 3 | asau
# Processing Record 9 of Set 3 | conceicao das alagoas
# Processing Record 10 of Set 3 | saint george
# Processing Record 11 of Set 3 | wolverhampton
# Processing Record 12 of Set 3 | osakarovka
# Processing Record 13 of Set 3 | lagoa
# Processing Record 14 of Set 3 | maraa
# Processing Record 15 of Set 3 | jati
# Processing Record 16 of Set 3 | cayambe
# Processing Record 17 of Set 3 | adrar
# Processing Record 18 of Set 3 | aswan
# Processing Record 19 of Set 3 | bima
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | tchibanga
# Processing Record 22 of Set 3 | biak
# Processing Record 23 of Set 3 | glendive
# Processing Record 24 of Set 3 | isla mujeres
# Processing Record 25 of Set 3 | crestview
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | carnarvon
# Processing Record 29 of Set 3 | san andres
# Processing Record 30 of Set 3 | kibala
# Processing Record 31 of Set 3 | gornoye loo
# Processing Record 32 of Set 3 | broken hill
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | bograd
# Processing Record 35 of Set 3 | margate
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | green river
# Processing Record 38 of Set 3 | muli
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | severo-kurilsk
# Processing Record 41 of Set 3 | tarko-sale
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | namatanai
# Processing Record 44 of Set 3 | bilma
# Processing Record 45 of Set 3 | uinskoye
# Processing Record 46 of Set 3 | poum
# Processing Record 47 of Set 3 | maxixe
# Processing Record 48 of Set 3 | firminy
# Processing Record 49 of Set 3 | shevchenkove
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | petropavlovka
# Processing Record 2 of Set 4 | arlit
# Processing Record 3 of Set 4 | zyryanka
# Processing Record 4 of Set 4 | dubbo
# Processing Record 5 of Set 4 | san carlos de bariloche
# Processing Record 6 of Set 4 | sikonge
# Processing Record 7 of Set 4 | hami
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | marawi
# Processing Record 11 of Set 4 | pacific grove
# Processing Record 12 of Set 4 | burnie
# Processing Record 13 of Set 4 | port elizabeth
# Processing Record 14 of Set 4 | barentu
# Processing Record 15 of Set 4 | erzin
# Processing Record 16 of Set 4 | ishigaki
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | san quintin
# Processing Record 19 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 4 | luanda
# Processing Record 21 of Set 4 | alofi
# Processing Record 22 of Set 4 | chifeng
# Processing Record 23 of Set 4 | malinyi
# Processing Record 24 of Set 4 | lethbridge
# Processing Record 25 of Set 4 | ancud
# Processing Record 26 of Set 4 | oktyabrskoye
# Processing Record 27 of Set 4 | grande prairie
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | daru
# Processing Record 30 of Set 4 | katsuura
# Processing Record 31 of Set 4 | kenai
# Processing Record 32 of Set 4 | tuban
# Processing Record 33 of Set 4 | san patricio
# Processing Record 34 of Set 4 | parchim
# Processing Record 35 of Set 4 | senador jose porfirio
# Processing Record 36 of Set 4 | taoudenni
# Processing Record 37 of Set 4 | viedma
# Processing Record 38 of Set 4 | volchansk
# Processing Record 39 of Set 4 | caravelas
# Processing Record 40 of Set 4 | sayyan
# Processing Record 41 of Set 4 | kununurra
# Processing Record 42 of Set 4 | brive-la-gaillarde
# Processing Record 43 of Set 4 | bathsheba
# Processing Record 44 of Set 4 | antofagasta
# Processing Record 45 of Set 4 | catuday
# Processing Record 46 of Set 4 | moree
# Processing Record 47 of Set 4 | muisne
# Processing Record 48 of Set 4 | narsaq
# Processing Record 49 of Set 4 | shumskiy
# Processing Record 50 of Set 4 | alenquer
# Processing Record 1 of Set 5 | maragogi
# Processing Record 2 of Set 5 | barcelos
# Processing Record 3 of Set 5 | qarqin
# Processing Record 4 of Set 5 | clinton
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | xuddur
# Processing Record 7 of Set 5 | ust-kuyga
# Processing Record 8 of Set 5 | walla walla
# Processing Record 9 of Set 5 | toccoa
# Processing Record 10 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 5 | khammam
# Processing Record 12 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 13 of Set 5 | denpasar
# Processing Record 14 of Set 5 | khani
# Processing Record 15 of Set 5 | raga
# Processing Record 16 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 5 | santa cruz
# Processing Record 18 of Set 5 | cabo san lucas
# Processing Record 19 of Set 5 | aklavik
# Processing Record 20 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 5 | tanout
# Processing Record 22 of Set 5 | vaini
# Processing Record 23 of Set 5 | pskent
# City not found. Skipping...
# Processing Record 24 of Set 5 | les cayes
# Processing Record 25 of Set 5 | mehriz
# Processing Record 26 of Set 5 | kalabo
# Processing Record 27 of Set 5 | gravdal
# Processing Record 28 of Set 5 | kazerun
# Processing Record 29 of Set 5 | quatre cocos
# Processing Record 30 of Set 5 | nabire
# Processing Record 31 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | camacha
# Processing Record 34 of Set 5 | san juan
# Processing Record 35 of Set 5 | avarua
# Processing Record 36 of Set 5 | santa rosa
# Processing Record 37 of Set 5 | feijo
# Processing Record 38 of Set 5 | alyangula
# Processing Record 39 of Set 5 | nipawin
# Processing Record 40 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | okha
# Processing Record 43 of Set 5 | souillac
# Processing Record 44 of Set 5 | pisco
# Processing Record 45 of Set 5 | roebourne
# Processing Record 46 of Set 5 | cockburn town
# Processing Record 47 of Set 5 | dolores
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | iquitos
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | piacabucu
# Processing Record 2 of Set 6 | weatherford
# Processing Record 3 of Set 6 | ketchikan
# Processing Record 4 of Set 6 | georgetown
# Processing Record 5 of Set 6 | dikson
# Processing Record 6 of Set 6 | addis zemen
# City not found. Skipping...
# Processing Record 7 of Set 6 | kortenberg
# Processing Record 8 of Set 6 | bethel
# Processing Record 9 of Set 6 | pemangkat
# Processing Record 10 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 6 | bucerias
# Processing Record 12 of Set 6 | agutaya
# Processing Record 13 of Set 6 | urrao
# Processing Record 14 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 15 of Set 6 | lakes entrance
# Processing Record 16 of Set 6 | batetskiy
# Processing Record 17 of Set 6 | maceio
# Processing Record 18 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 6 | inhambane
# Processing Record 20 of Set 6 | westerland
# Processing Record 21 of Set 6 | coihaique
# Processing Record 22 of Set 6 | jadu
# Processing Record 23 of Set 6 | portland
# Processing Record 24 of Set 6 | asosa
# Processing Record 25 of Set 6 | kamenka
# Processing Record 26 of Set 6 | riyadh
# Processing Record 27 of Set 6 | negombo
# Processing Record 28 of Set 6 | wattegama
# Processing Record 29 of Set 6 | iqaluit
# Processing Record 30 of Set 6 | terrace
# Processing Record 31 of Set 6 | shache
# Processing Record 32 of Set 6 | den helder
# Processing Record 33 of Set 6 | kasangulu
# Processing Record 34 of Set 6 | pundaguitan
# Processing Record 35 of Set 6 | sobolevo
# Processing Record 36 of Set 6 | saldanha
# Processing Record 37 of Set 6 | arman
# Processing Record 38 of Set 6 | mandera
# Processing Record 39 of Set 6 | cubarral
# Processing Record 40 of Set 6 | neryungri
# Processing Record 41 of Set 6 | alexandria
# Processing Record 42 of Set 6 | kibakwe
# Processing Record 43 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 6 | atar
# Processing Record 45 of Set 6 | uglovskoye
# Processing Record 46 of Set 6 | tonekabon
# Processing Record 47 of Set 6 | puteyets
# Processing Record 48 of Set 6 | klamath falls
# Processing Record 49 of Set 6 | tacna
# Processing Record 50 of Set 6 | augusto correa
# Processing Record 1 of Set 7 | wellington
# Processing Record 2 of Set 7 | cidreira
# Processing Record 3 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 7 | luba
# Processing Record 5 of Set 7 | ribeira grande
# Processing Record 6 of Set 7 | buchanan
# Processing Record 7 of Set 7 | henties bay
# Processing Record 8 of Set 7 | neiafu
# Processing Record 9 of Set 7 | ambo
# Processing Record 10 of Set 7 | geraldton
# Processing Record 11 of Set 7 | beira
# Processing Record 12 of Set 7 | togur
# Processing Record 13 of Set 7 | oranjemund
# Processing Record 14 of Set 7 | gat
# Processing Record 15 of Set 7 | pointe michel
# Processing Record 16 of Set 7 | klaksvik
# Processing Record 17 of Set 7 | general pico
# Processing Record 18 of Set 7 | banda aceh
# Processing Record 19 of Set 7 | meadow lake
# Processing Record 20 of Set 7 | muros
# Processing Record 21 of Set 7 | lavrentiya
# Processing Record 22 of Set 7 | asfi
# Processing Record 23 of Set 7 | acapulco
# Processing Record 24 of Set 7 | bukavu
# Processing Record 25 of Set 7 | harper
# Processing Record 26 of Set 7 | dhanwar
# Processing Record 27 of Set 7 | baykit
# Processing Record 28 of Set 7 | playas
# Processing Record 29 of Set 7 | monterey
# Processing Record 30 of Set 7 | ahipara
# Processing Record 31 of Set 7 | codrington
# Processing Record 32 of Set 7 | airai
# Processing Record 33 of Set 7 | beidao
# Processing Record 34 of Set 7 | quibdo
# Processing Record 35 of Set 7 | saint-pierre
# Processing Record 36 of Set 7 | paracatu
# Processing Record 37 of Set 7 | patacamaya
# Processing Record 38 of Set 7 | lauro muller
# Processing Record 39 of Set 7 | tateyama
# Processing Record 40 of Set 7 | sur
# Processing Record 41 of Set 7 | okhotsk
# Processing Record 42 of Set 7 | rondonopolis
# Processing Record 43 of Set 7 | douglas
# Processing Record 44 of Set 7 | flin flon
# Processing Record 45 of Set 7 | fairbanks
# Processing Record 46 of Set 7 | qaqortoq
# Processing Record 47 of Set 7 | kichmengskiy gorodok
# Processing Record 48 of Set 7 | palencia
# Processing Record 49 of Set 7 | bardiyah
# Processing Record 50 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 8 | havoysund
# Processing Record 2 of Set 8 | nerchinskiy zavod
# Processing Record 3 of Set 8 | blonduos
# City not found. Skipping...
# Processing Record 4 of Set 8 | ugarcin
# City not found. Skipping...
# Processing Record 5 of Set 8 | tevaitoa
# Processing Record 6 of Set 8 | yarada
# Processing Record 7 of Set 8 | esna
# Processing Record 8 of Set 8 | jega
# Processing Record 9 of Set 8 | tehachapi
# Processing Record 10 of Set 8 | kahului
# Processing Record 11 of Set 8 | ribeirao bonito
# Processing Record 12 of Set 8 | opuwo
# Processing Record 13 of Set 8 | gizo
# Processing Record 14 of Set 8 | tiksi
# Processing Record 15 of Set 8 | garden city
# Processing Record 16 of Set 8 | norman wells
# Processing Record 17 of Set 8 | lar gerd
# City not found. Skipping...
# Processing Record 18 of Set 8 | muncie
# Processing Record 19 of Set 8 | dayong
# Processing Record 20 of Set 8 | altamont
# Processing Record 21 of Set 8 | beboto
# Processing Record 22 of Set 8 | kibaya
# Processing Record 23 of Set 8 | ojuelos de jalisco
# Processing Record 24 of Set 8 | starosubkhangulovo
# Processing Record 25 of Set 8 | kormilovka
# Processing Record 26 of Set 8 | ostrovnoy
# Processing Record 27 of Set 8 | faya
# Processing Record 28 of Set 8 | almenevo
# City not found. Skipping...
# Processing Record 29 of Set 8 | kantang
# Processing Record 30 of Set 8 | manica
# Processing Record 31 of Set 8 | avera
# Processing Record 32 of Set 8 | kananga
# Processing Record 33 of Set 8 | hovd
# Processing Record 34 of Set 8 | tabou
# Processing Record 35 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 8 | diebougou
# Processing Record 38 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 8 | kidal
# Processing Record 40 of Set 8 | broome
# Processing Record 41 of Set 8 | munxar
# Processing Record 42 of Set 8 | puerto madero
# Processing Record 43 of Set 8 | brodokalmak
# Processing Record 44 of Set 8 | meulaboh
# Processing Record 45 of Set 8 | cabinda
# Processing Record 46 of Set 8 | voi
# Processing Record 47 of Set 8 | abatskoye
# Processing Record 48 of Set 8 | wajir
# Processing Record 49 of Set 8 | nome
# Processing Record 50 of Set 8 | coromandel
# Processing Record 1 of Set 9 | comodoro rivadavia
# Processing Record 2 of Set 9 | college
# Processing Record 3 of Set 9 | seminole
# Processing Record 4 of Set 9 | yar-sale
# Processing Record 5 of Set 9 | kropotkin
# Processing Record 6 of Set 9 | chemax
# Processing Record 7 of Set 9 | kathu
# Processing Record 8 of Set 9 | richard toll
# City not found. Skipping...
# Processing Record 9 of Set 9 | guantanamo
# Processing Record 10 of Set 9 | port-gentil
# Processing Record 11 of Set 9 | port hardy
# Processing Record 12 of Set 9 | olafsvik
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | dunda
# Processing Record 15 of Set 9 | iquique
# Processing Record 16 of Set 9 | honningsvag
# Processing Record 17 of Set 9 | rawson
# Processing Record 18 of Set 9 | ankang
# Processing Record 19 of Set 9 | vila franca do campo
# Processing Record 20 of Set 9 | vestmannaeyjar
# Processing Record 21 of Set 9 | hirara
# Processing Record 22 of Set 9 | tezu
# Processing Record 23 of Set 9 | miles city
# Processing Record 24 of Set 9 | gorakhpur
# Processing Record 25 of Set 9 | odesskoye
# Processing Record 26 of Set 9 | rantepao
# Processing Record 27 of Set 9 | yenotayevka
# Processing Record 28 of Set 9 | bundaberg
# Processing Record 29 of Set 9 | kudahuvadhoo
# Processing Record 30 of Set 9 | constitucion
# Processing Record 31 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 9 | mkushi
# Processing Record 33 of Set 9 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 34 of Set 9 | stykkisholmur
# Processing Record 35 of Set 9 | half moon bay
# Processing Record 36 of Set 9 | darnah
# Processing Record 37 of Set 9 | grand baie
# Processing Record 38 of Set 9 | samana
# Processing Record 39 of Set 9 | falam
# Processing Record 40 of Set 9 | athabasca
# Processing Record 41 of Set 9 | hailar
# Processing Record 42 of Set 9 | khatanga
# Processing Record 43 of Set 9 | wasilla
# Processing Record 44 of Set 9 | shamary
# Processing Record 45 of Set 9 | whitehorse
# Processing Record 46 of Set 9 | hyeres
# Processing Record 47 of Set 9 | barcelona
# Processing Record 48 of Set 9 | hobyo
# Processing Record 49 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 9 | edmundston
# Processing Record 1 of Set 10 | stornoway
# Processing Record 2 of Set 10 | dingle
# Processing Record 3 of Set 10 | kloulklubed
# Processing Record 4 of Set 10 | nampa
# Processing Record 5 of Set 10 | jurmala
# Processing Record 6 of Set 10 | pandan
# Processing Record 7 of Set 10 | nanortalik
# Processing Record 8 of Set 10 | aksarka
# Processing Record 9 of Set 10 | omboue
# Processing Record 10 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 11 of Set 10 | la union
# Processing Record 12 of Set 10 | seryshevo
# Processing Record 13 of Set 10 | shakawe
# Processing Record 14 of Set 10 | jambi
# Processing Record 15 of Set 10 | jalingo
# Processing Record 16 of Set 10 | fort nelson
# Processing Record 17 of Set 10 | bodden town
# Processing Record 18 of Set 10 | great falls
# Processing Record 19 of Set 10 | tomatlan
# Processing Record 20 of Set 10 | scarborough
# Processing Record 21 of Set 10 | tessalit
# Processing Record 22 of Set 10 | wageningen
# Processing Record 23 of Set 10 | ilulissat
# Processing Record 24 of Set 10 | danielskuil
# Processing Record 25 of Set 10 | batemans bay
# Processing Record 26 of Set 10 | benjamin aceval
# Processing Record 27 of Set 10 | rio bravo
# Processing Record 28 of Set 10 | kyra
# Processing Record 29 of Set 10 | mapimi
# Processing Record 30 of Set 10 | batsfjord
# Processing Record 31 of Set 10 | pahrump
# Processing Record 32 of Set 10 | shaunavon
# Processing Record 33 of Set 10 | birjand
# Processing Record 34 of Set 10 | alice springs
# Processing Record 35 of Set 10 | marzuq
# Processing Record 36 of Set 10 | mount gambier
# Processing Record 37 of Set 10 | dhankuta
# Processing Record 38 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 10 | cabedelo
# Processing Record 40 of Set 10 | williston
# Processing Record 41 of Set 10 | talovaya
# Processing Record 42 of Set 10 | dromolaxia
# Processing Record 43 of Set 10 | cabra
# Processing Record 44 of Set 10 | qandala
# Processing Record 45 of Set 10 | navapur
# City not found. Skipping...
# Processing Record 46 of Set 10 | sinnamary
# Processing Record 47 of Set 10 | nador
# Processing Record 48 of Set 10 | bonthe
# Processing Record 49 of Set 10 | aksum
# Processing Record 50 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 11 | kargasok
# Processing Record 2 of Set 11 | longyearbyen
# Processing Record 3 of Set 11 | petropavlivka
# Processing Record 4 of Set 11 | cayenne
# Processing Record 5 of Set 11 | cambrils
# Processing Record 6 of Set 11 | talas
# Processing Record 7 of Set 11 | rosetta
# Processing Record 8 of Set 11 | ballina
# Processing Record 9 of Set 11 | kalmunai
# Processing Record 10 of Set 11 | monte alegre
# Processing Record 11 of Set 11 | taltal
# Processing Record 12 of Set 11 | andros town
# Processing Record 13 of Set 11 | igrim
# Processing Record 14 of Set 11 | salinopolis
# Processing Record 15 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 11 | afua
# Processing Record 17 of Set 11 | winona
# Processing Record 18 of Set 11 | whyalla
# Processing Record 19 of Set 11 | makow mazowiecki
# Processing Record 20 of Set 11 | brigantine
# Processing Record 21 of Set 11 | montescaglioso
# Processing Record 22 of Set 11 | kouroussa
# Processing Record 23 of Set 11 | china
# Processing Record 24 of Set 11 | haines junction
# Processing Record 25 of Set 11 | yeehaw junction
# City not found. Skipping...
# Processing Record 26 of Set 11 | saint-augustin
# Processing Record 27 of Set 11 | silvi
# Processing Record 28 of Set 11 | freeport
# Processing Record 29 of Set 11 | aykhal
# Processing Record 30 of Set 11 | oussouye
# Processing Record 31 of Set 11 | awjilah
# Processing Record 32 of Set 11 | usvyaty
# Processing Record 33 of Set 11 | fukue
# Processing Record 34 of Set 11 | kodinsk
# Processing Record 35 of Set 11 | bria
# Processing Record 36 of Set 11 | kashi
# Processing Record 37 of Set 11 | sawtell
# Processing Record 38 of Set 11 | husavik
# Processing Record 39 of Set 11 | nassau
# Processing Record 40 of Set 11 | novaya malykla
# Processing Record 41 of Set 11 | alampur
# Processing Record 42 of Set 11 | krasnoselkup
# Processing Record 43 of Set 11 | novopavlovka
# Processing Record 44 of Set 11 | necochea
# Processing Record 45 of Set 11 | korla
# Processing Record 46 of Set 11 | manakara
# Processing Record 47 of Set 11 | orlik
# Processing Record 48 of Set 11 | gushikawa
# Processing Record 49 of Set 11 | matinhos
# Processing Record 50 of Set 11 | la ronge
# Processing Record 1 of Set 12 | berlevag
# Processing Record 2 of Set 12 | port blair
# Processing Record 3 of Set 12 | nichinan
# Processing Record 4 of Set 12 | umm lajj
# Processing Record 5 of Set 12 | flinders
# Processing Record 6 of Set 12 | ambilobe
# Processing Record 7 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 12 | privolzhye
# Processing Record 9 of Set 12 | neftcala
# Processing Record 10 of Set 12 | laguna
# Processing Record 11 of Set 12 | nouadhibou
# Processing Record 12 of Set 12 | manbij
# Processing Record 13 of Set 12 | beloha
# Processing Record 14 of Set 12 | shimoda
# Processing Record 15 of Set 12 | terra santa
# Processing Record 16 of Set 12 | vilhena
# Processing Record 17 of Set 12 | sitka
# Processing Record 18 of Set 12 | ilinskiy
# Processing Record 19 of Set 12 | jumla
# Processing Record 20 of Set 12 | jhang
# Processing Record 21 of Set 12 | gorontalo
# Processing Record 22 of Set 12 | warwick
# Processing Record 23 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 24 of Set 12 | mangrol
# Processing Record 25 of Set 12 | ucluelet
# Processing Record 26 of Set 12 | vila velha
# Processing Record 27 of Set 12 | rabo de peixe
# Processing Record 28 of Set 12 | karratha
# Processing Record 29 of Set 12 | magalia
# Processing Record 30 of Set 12 | rio gallegos
# Processing Record 31 of Set 12 | manado
# Processing Record 32 of Set 12 | sola
# Processing Record 33 of Set 12 | eenhana
# Processing Record 34 of Set 12 | yetholm
# City not found. Skipping...
# Processing Record 35 of Set 12 | mambajao
# Processing Record 36 of Set 12 | ramanuj ganj
# Processing Record 37 of Set 12 | camargo
# Processing Record 38 of Set 12 | rajula
# Processing Record 39 of Set 12 | umm kaddadah
# Processing Record 40 of Set 12 | zeya
# Processing Record 41 of Set 12 | celestun
# Processing Record 42 of Set 12 | auki
# Processing Record 43 of Set 12 | ojinaga
# Processing Record 44 of Set 12 | soyo
# Processing Record 45 of Set 12 | kapuskasing
# Processing Record 46 of Set 12 | alekseyevka
# Processing Record 47 of Set 12 | brasilia
# Processing Record 48 of Set 12 | itarema
# Processing Record 49 of Set 12 | johnshaven
# Processing Record 50 of Set 12 | bereda
# Processing Record 1 of Set 13 | yumen
# Processing Record 2 of Set 13 | doka
# Processing Record 3 of Set 13 | rio claro
# Processing Record 4 of Set 13 | pimenteiras
# Processing Record 5 of Set 13 | estelle
# Processing Record 6 of Set 13 | montes altos
# Processing Record 7 of Set 13 | grand gaube
# Processing Record 8 of Set 13 | mangan
# Processing Record 9 of Set 13 | kulachi
# Processing Record 10 of Set 13 | keflavik
# Processing Record 11 of Set 13 | pulaski
# Processing Record 12 of Set 13 | boa vista
# Processing Record 13 of Set 13 | shirokiy
# Processing Record 14 of Set 13 | winnemucca
# Processing Record 15 of Set 13 | san cristobal
# Processing Record 16 of Set 13 | matara
# Processing Record 17 of Set 13 | xinxiang
# Processing Record 18 of Set 13 | juegang
# Processing Record 19 of Set 13 | vestmanna
# Processing Record 20 of Set 13 | salta
# Processing Record 21 of Set 13 | fort wellington
# Processing Record 22 of Set 13 | visby
# Processing Record 23 of Set 13 | yudong
# Processing Record 24 of Set 13 | bakchar
# Processing Record 25 of Set 13 | bambanglipuro
# Processing Record 26 of Set 13 | mount isa
# Processing Record 27 of Set 13 | dovers
# Processing Record 28 of Set 13 | isangel
# Processing Record 29 of Set 13 | arona
# Processing Record 30 of Set 13 | afyonkarahisar
# Processing Record 31 of Set 13 | baruun-urt
# Processing Record 32 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 13 | muravlenko
# Processing Record 34 of Set 13 | batticaloa
# Processing Record 35 of Set 13 | batagay-alyta
# Processing Record 36 of Set 13 | lumphat
# Processing Record 37 of Set 13 | lasa
# Processing Record 38 of Set 13 | cascais
# Processing Record 39 of Set 13 | camopi
# Processing Record 40 of Set 13 | waddan
# Processing Record 41 of Set 13 | gamba
# Processing Record 42 of Set 13 | kutoarjo
# Processing Record 43 of Set 13 | bandarbeyla
# Processing Record 44 of Set 13 | ponta delgada
# Processing Record 45 of Set 13 | port washington
# Processing Record 46 of Set 13 | kaspiyskiy
# Processing Record 47 of Set 13 | dongsheng
# Processing Record 48 of Set 13 | mufulira
# Processing Record 49 of Set 13 | srednekolymsk
# Processing Record 50 of Set 13 | egvekinot
# Processing Record 1 of Set 14 | vila nova de milfontes
# Processing Record 2 of Set 14 | buedu
# Processing Record 3 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 4 of Set 14 | masuguru
# Processing Record 5 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 14 | bama
# Processing Record 7 of Set 14 | upata
# Processing Record 8 of Set 14 | santa cruz del norte
# Processing Record 9 of Set 14 | ust-omchug
# Processing Record 10 of Set 14 | the valley
# Processing Record 11 of Set 14 | fayaoue
# Processing Record 12 of Set 14 | prince albert
# Processing Record 13 of Set 14 | ndele
# Processing Record 14 of Set 14 | rincon
# Processing Record 15 of Set 14 | jishou
# Processing Record 16 of Set 14 | eten
# Processing Record 17 of Set 14 | severnyy
# Processing Record 18 of Set 14 | mujiayingzi
# Processing Record 19 of Set 14 | zwedru
# Processing Record 20 of Set 14 | sorrento
# Processing Record 21 of Set 14 | altamira
# Processing Record 22 of Set 14 | yokadouma
# Processing Record 23 of Set 14 | nicoya
# Processing Record 24 of Set 14 | mezen
# Processing Record 25 of Set 14 | ulladulla
# Processing Record 26 of Set 14 | catalina
# Processing Record 27 of Set 14 | biga
# Processing Record 28 of Set 14 | buraydah
# Processing Record 29 of Set 14 | gardan diwal
# City not found. Skipping...
# Processing Record 30 of Set 14 | bredy
# Processing Record 31 of Set 14 | kandrian
# Processing Record 32 of Set 14 | madang
# Processing Record 33 of Set 14 | urumqi
# Processing Record 34 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 35 of Set 14 | hit
# Processing Record 36 of Set 14 | moose factory
# Processing Record 37 of Set 14 | dingzhou
# Processing Record 38 of Set 14 | labuhan
# Processing Record 39 of Set 14 | arapiraca
# Processing Record 40 of Set 14 | campos altos
# Processing Record 41 of Set 14 | taseyevo
# Processing Record 42 of Set 14 | hambantota
# Processing Record 43 of Set 14 | samarai
# Processing Record 44 of Set 14 | gazojak
# Processing Record 45 of Set 14 | porbandar
# Processing Record 46 of Set 14 | pinawa
# Processing Record 47 of Set 14 | fountain hills
# Processing Record 48 of Set 14 | west bay
# Processing Record 49 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 14 | ridgecrest
# Processing Record 1 of Set 15 | yichang
# Processing Record 2 of Set 15 | tambura
# Processing Record 3 of Set 15 | svetlogorsk
# Processing Record 4 of Set 15 | araouane
# Processing Record 5 of Set 15 | toora-khem
# Processing Record 6 of Set 15 | pimentel
# Processing Record 7 of Set 15 | puerto varas
# Processing Record 8 of Set 15 | ribeira brava
# Processing Record 9 of Set 15 | ipixuna
# Processing Record 10 of Set 15 | kautokeino
# Processing Record 11 of Set 15 | wagar
# Processing Record 12 of Set 15 | a coruna
# Processing Record 13 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 15 | novobirilyussy
# Processing Record 15 of Set 15 | coruripe
# Processing Record 16 of Set 15 | panaba
# Processing Record 17 of Set 15 | angra
# City not found. Skipping...
# Processing Record 18 of Set 15 | lancaster
# Processing Record 19 of Set 15 | fiumicino
# Processing Record 20 of Set 15 | keti bandar
# Processing Record 21 of Set 15 | nelson bay
# Processing Record 22 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 15 | wajid
# Processing Record 24 of Set 15 | mata
# Processing Record 25 of Set 15 | beringovskiy
# Processing Record 26 of Set 15 | lugazi
# Processing Record 27 of Set 15 | mantua
# Processing Record 28 of Set 15 | merritt island
# Processing Record 29 of Set 15 | mysliborz
# Processing Record 30 of Set 15 | roma
# Processing Record 31 of Set 15 | zonguldak
# Processing Record 32 of Set 15 | beipiao
# Processing Record 33 of Set 15 | nassjo
# Processing Record 34 of Set 15 | puerto pinasco
# City not found. Skipping...
# Processing Record 35 of Set 15 | kourou
# Processing Record 36 of Set 15 | kanuma
# Processing Record 37 of Set 15 | loa janan
# Processing Record 38 of Set 15 | los llanos de aridane
# Processing Record 39 of Set 15 | sabang
# Processing Record 40 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 15 | sechura
# Processing Record 42 of Set 15 | praxedis guerrero
# Processing Record 43 of Set 15 | powell river
# Processing Record 44 of Set 15 | te anau
# Processing Record 45 of Set 15 | yaan
# Processing Record 46 of Set 15 | lar
# Processing Record 47 of Set 15 | matucana
# Processing Record 48 of Set 15 | itaueira
# Processing Record 49 of Set 15 | agadez
# Processing Record 50 of Set 15 | bartica
# Processing Record 1 of Set 16 | togul
# Processing Record 2 of Set 16 | ayorou
# Processing Record 3 of Set 16 | ouidah
# Processing Record 4 of Set 16 | saquena
# Processing Record 5 of Set 16 | goksun
# Processing Record 6 of Set 16 | ahumada
# City not found. Skipping...
# Processing Record 7 of Set 16 | waslala
# Processing Record 8 of Set 16 | zhaotong
# Processing Record 9 of Set 16 | berezovka
# Processing Record 10 of Set 16 | mnogovershinnyy
# Processing Record 11 of Set 16 | horconcitos
# Processing Record 12 of Set 16 | scalea
# Processing Record 13 of Set 16 | bako
# Processing Record 14 of Set 16 | wuchang
# Processing Record 15 of Set 16 | gatton
# Processing Record 16 of Set 16 | anadyr
# Processing Record 17 of Set 16 | gornopravdinsk
# Processing Record 18 of Set 16 | timoteo
# Processing Record 19 of Set 16 | puerto suarez
# Processing Record 20 of Set 16 | kruisfontein
# Processing Record 21 of Set 16 | westpunt
# City not found. Skipping...
# Processing Record 22 of Set 16 | padang
# Processing Record 23 of Set 16 | christchurch
# Processing Record 24 of Set 16 | labuan
# Processing Record 25 of Set 16 | contamana
# Processing Record 26 of Set 16 | jiangyou
# Processing Record 27 of Set 16 | north bend
# Processing Record 28 of Set 16 | waipawa
# Processing Record 29 of Set 16 | vigia del fuerte
# Processing Record 30 of Set 16 | norsup
# Processing Record 31 of Set 16 | fianga
# City not found. Skipping...
# Processing Record 32 of Set 16 | narsingi
# Processing Record 33 of Set 16 | sept-iles
# Processing Record 34 of Set 16 | odweyne
# Processing Record 35 of Set 16 | jomalig
# City not found. Skipping...
# Processing Record 36 of Set 16 | fare
# Processing Record 37 of Set 16 | sovetskiy
# Processing Record 38 of Set 16 | cam pha
# City not found. Skipping...
# Processing Record 39 of Set 16 | palmer
# Processing Record 40 of Set 16 | arrecife
# Processing Record 41 of Set 16 | mercedes
# Processing Record 42 of Set 16 | nouakchott
# Processing Record 43 of Set 16 | pontes e lacerda
# Processing Record 44 of Set 16 | tura
# Processing Record 45 of Set 16 | praia da vitoria
# Processing Record 46 of Set 16 | birin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# [{'City': 'Dunedin', 'Lat': -45.8742, 'Lng': 170.5036, 'Max Temp': 286.58, 'Humidity': 92, 'Cloudiness': 100, 'Wind Speed': 5.62, 'Country': 'NZ', 'Current Description': 'overcast clouds'}, {'City': 'Upernavik', 'Lat': 72.7868, 'Lng': -56.1549, 'Max Temp': 242.52, 'Humidity': 98, 'Cloudiness': 81, 'Wind Speed': 2.87, 'Country': 'GL', 'Current Description': 'broken clouds'}, {'City': 'Punta Arenas', 'Lat': -53.15, 'Lng': -70.9167, 'Max Temp': 286.21, 'Humidity': 67, 'Cloudiness': 0, 'Wind Speed': 5.14, 'Country': 'CL', 'Current Description': 'clear sky'}, {'City': 'Rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 299.19, 'Humidity': 77, 'Cloudiness': 34, 'Wind Speed': 8.17, 'Country': 'PF', 'Current Description': 'light rain'}, {'City': 'Busselton', 'Lat': -33.65, 'Lng': 115.3333, 'Max Temp': 292.48, 'Humidity': 60, 'Cloudiness': 4, 'Wind Speed': 3.23, 'Country': 'AU', 'Current Description': 'clear sky'}, {'City': 'Atuona', 'Lat': -9.8, 'Lng': -139.0333, 'Max Temp': 299.18, 'Humidity': 69, 'Cloudiness': 2, 'Wind Speed': 5.65, 'Country': 'PF', 'Current Description': 'clear sky'}, {'City': 'Palana', 'Lat': 59.1167, 'Lng': 159.9667, 'Max Temp': 253.95, 'Humidity': 94, 'Cloudiness': 77, 'Wind Speed': 3.29, 'Country': 'RU', 'Current Description': 'broken clouds'}, {'City': 'Penticton', 'Lat': 49.4806, 'Lng': -119.5858, 'Max Temp': 279.03, 'Humidity': 87, 'Cloudiness': 75, 'Wind Speed': 2.06, 'Country': 'CA', 'Current Description': 'broken clouds'}, {'City': 'Hithadhoo', 'Lat': -0.6, 'Lng': 73.0833, 'Max Temp': 300.57, 'Humidity': 75, 'Cloudiness': 100, 'Wind Speed': 5.36, 'Country': 'MV', 'Current Description': 'overcast clouds'}, {'City': 'Lochgilphead', 'Lat': 56.038, 'Lng': -5.4321, 'Max Temp': 279.53, 'Humidity': 81, 'Cloudiness': 69, 'Wind Speed': 9.01, 'Country': 'GB', 'Current Description': 'broken clouds'}, {'City': 'Arraial do Cabo', 'Lat': -22.9661, 'Lng': -42.0278, 'Max Temp': 297.07, 'Humidity': 100, 'Cloudiness': 75, 'Wind Speed': 1.03, 'Country': 'BR', 'Current Description': 'broken clouds'}, {'City': 'Mataura', 'Lat': -46.1927, 'Lng': 168.8643, 'Max Temp': 285.32, 'Humidity': 94, 'Cloudiness': 100, 'Wind Speed': 1.64, 'Country': 'NZ', 'Current Description': 'overcast clouds'}, {'City': 'Esperance', 'Lat': -33.8667, 'Lng': 121.9, 'Max Temp': 295.31, 'Humidity': 74, 'Cloudiness': 4, 'Wind Speed': 7.5, 'Country': 'AU', 'Current Description': 'clear sky'}, {'City': 'Hong Kong', 'Lat': 22.2855, 'Lng': 114.1577, 'Max Temp': 291.45, 'Humidity': 94, 'Cloudiness': 99, 'Wind Speed': 7.82, 'Country': 'HK', 'Current Description': 'overcast clouds'}, {'City': 'Mahébourg', 'Lat': -20.4081, 'Lng': 57.7, 'Max Temp': 297.31, 'Humidity': 83, 'Cloudiness': 75, 'Wind Speed': 2.06, 'Country': 'MU', 'Current Description': 'broken clouds'}, {'City': 'Lüderitz', 'Lat': -26.6481, 'Lng': 15.1594, 'Max Temp': 292.08, 'Humidity': 73, 'Cloudiness': 100, 'Wind Speed': 3.08, 'Country': 'NA', 'Current Description': 'overcast clouds'}, {'City': 'Coquimbo', 'Lat': -29.9533, 'Lng': -71.3436, 'Max Temp': 292, 'Humidity': 82, 'Cloudiness': 20, 'Wind Speed': 4.12, 'Country': 'CL', 'Current Description': 'few clouds'}, {'City': 'Dingtao', 'Lat': 35.0683, 'Lng': 115.5625, 'Max Temp': 274.16, 'Humidity': 76, 'Cloudiness': 1, 'Wind Speed': 2.8, 'Country': 'CN', 'Current Description': 'clear sky'}, {'City': 'Mehamn', 'Lat': 71.0357, 'Lng': 27.8492, 'Max Temp': 268.12, 'Humidity': 80, 'Cloudiness': 99, 'Wind Speed': 3.09, 'Country': 'NO', 'Current Description': 'overcast clouds'}, {'City': 'Mar del Plata', 'Lat': -38.0023, 'Lng': -57.5575, 'Max Temp': 295.98, 'Humidity': 88, 'Cloudiness': 0, 'Wind Speed': 8.05, 'Country': 'AR', 'Current Description': 'clear sky'}, {'City': 'Puerto Ayora', 'Lat': -0.7393, 'Lng': -90.3518, 'Max Temp': 296.23, 'Humidity': 89, 'Cloudiness': 23, 'Wind Speed': 1.79, 'Country': 'EC', 'Current Description': 'few clouds'}, {'City': 'Albany', 'Lat': 42.6001, 'Lng': -73.9662, 'Max Temp': 271.81, 'Humidity': 74, 'Cloudiness': 84, ' ...

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 735

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Dunedin -45.8742  170.5036    286.58        92         100
# 1     Upernavik  72.7868  -56.1549    242.52        98          81
# 2  Punta Arenas -53.1500  -70.9167    286.21        67           0
# 3       Rikitea -23.1203 -134.9692    299.19        77          34
# 4     Busselton -33.6500  115.3333    292.48        60           4
# 5        Atuona  -9.8000 -139.0333    299.18        69           2
# 6        Palana  59.1167  159.9667    253.95        94          77
# 7     Penticton  49.4806 -119.5858    279.03        87          75
# 8     Hithadhoo  -0.6000   73.0833    300.57        75         100
# 9  Lochgilphead  56.0380   -5.4321    279.53        81          69
#
#    Wind Speed Country Current Description
# 0        5.62      NZ     overcast clouds
# 1        2.87      GL       broken clouds
# 2        5.14      CL           clear sky
# 3        8.17      PF          light rain
# 4        3.23      AU           clear sky
# 5        5.65      PF           clear sky
# 6        3.29      RU       broken clouds
# 7        2.06      CA       broken clouds
# 8        5.36      MV     overcast clouds
# 9        9.01      GB       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

reordered_column = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reordered_column] 


# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Dunedin      NZ -45.8742  170.5036    286.58        92         100
# 1     Upernavik      GL  72.7868  -56.1549    242.52        98          81
# 2  Punta Arenas      CL -53.1500  -70.9167    286.21        67           0
# 3       Rikitea      PF -23.1203 -134.9692    299.19        77          34
# 4     Busselton      AU -33.6500  115.3333    292.48        60           4
# 5        Atuona      PF  -9.8000 -139.0333    299.18        69           2
# 6        Palana      RU  59.1167  159.9667    253.95        94          77
# 7     Penticton      CA  49.4806 -119.5858    279.03        87          75
# 8     Hithadhoo      MV  -0.6000   73.0833    300.57        75         100
# 9  Lochgilphead      GB  56.0380   -5.4321    279.53        81          69
#
#    Wind Speed Current Description
# 0        5.62     overcast clouds
# 1        2.87       broken clouds
# 2        5.14           clear sky
# 3        8.17          light rain
# 4        3.23           clear sky
# 5        5.65           clear sky
# 6        3.29       broken clouds
# 7        2.06       broken clouds
# 8        5.36     overcast clouds
# 9        9.01       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
fileName = 'WeatherPy_database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(fileName, index_label="City_ID")
